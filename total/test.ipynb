# %%
import stim
import numpy as np
import magic

circuit = magic.magic_preparation(0,0,0,0,0,0.001)
circuit.diagram('timeline-svg')
# Out:
# <svg viewBox="0 0 27616 4512"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L27584,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L27584,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L27584,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L27584,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# <path id="qubit_line:4" d="M64,320 L27584,320 " stroke="black"/>
# ...

# %%
circuit.diagram('timeslice-svg')
# Out:
# <svg viewBox="0 0 4040.89 3552.14"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_dots">
# <circle id="qubit_dot:1:-7_0:0" cx="125.255" cy="125.255" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:2:-8_1:0" cx="80" cy="170.51" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:3:-7_1:0" cx="125.255" cy="170.51" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:4:-6_0:0" cx="170.51" cy="125.255" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:5:-5_0:0" cx="215.764" cy="125.255" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:6:-6_1:0" cx="170.51" cy="170.51" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:7:-5_1:0" cx="215.764" cy="170.51" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:8:-8_2:0" cx="80" cy="215.764" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:9:-7_2:0" cx="125.255" cy="215.764" r="2" stroke="none" fill="black"/>
# ...
